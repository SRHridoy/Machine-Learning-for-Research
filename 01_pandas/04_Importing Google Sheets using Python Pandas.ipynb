# %%
import pandas as pd

# %%
# pip install gspread
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts pyrsa-decrypt.exe, pyrsa-encrypt.exe, pyrsa-keygen.exe, pyrsa-priv2pub.exe, pyrsa-sign.exe and pyrsa-verify.exe are installed in 'C:\Users\Sohan\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script google-oauthlib-tool.exe is installed in 'C:\Users\Sohan\AppData\Roaming\Python\Python312\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import gspread

# %%
gc = gspread.service_account(filename=r"C:\Users\Sohan\OneDrive\Desktop\Research\pandas\testing-465014-dbb04443dd80.json")

# %%
gc

# %%
# Make sure you have shared the Google Sheet with your service account email!
# You can find the service account email in your JSON credentials file under "client_email".
sheet = gc.open_by_url('https://docs.google.com/spreadsheets/d/1xY6GJCGy9Hd17U_U-_EOoPbjMrD0q_JMupQGFgkuKqY/edit?usp=sharing')

# %%
sheet
# Out:
# <Spreadsheet 'To-do list' id:1xY6GJCGy9Hd17U_U-_EOoPbjMrD0q_JMupQGFgkuKqY>

# %%
# List all worksheet titles to find the correct name
print([ws.title for ws in sheet.worksheets()])
# Then use the correct worksheet name, for example:
# ws = sheet.worksheet('To do')  # Replace with the correct name from the list above
# Out:
# ['To do']

# %%
ws = sheet.worksheet('To do')

# %%
df = pd.DataFrame(ws.get_all_records())

# %%
df
# Out:
#    \n To Do                                          1/3 completed
# 0
# 1         ✓  Date                                               Task
# 2      TRUE   7/9    Type anything into column A to complete an item
# 3     FALSE   8/9  Change the styling of completed items under 'F...
# 4     FALSE   9/9  Sort items using the drop-down arrows next to ...
# 5     FALSE
# 6     FALSE
# 7     FALSE
# 8     FALSE
# 9     FALSE
# 10    FALSE
# 11    FALSE
# 12    FALSE
# 13    FALSE
# 14    FALSE
# 15    FALSE
# 16    FALSE
# 17    FALSE
# 18    FALSE
# 19    FALSE
# 20    FALSE
# 21    FALSE
# 22    FALSE
# 23    FALSE
# 24    FALSE
# 25    FALSE
# 26    FALSE
# 27    FALSE
# 28    FALSE
# 29    FALSE
# 30    FALSE
# 31    FALSE
# 32    FALSE
# 33    FALSE
# 34    FALSE
# 35    FALSE
# 36    FALSE
# 37    FALSE
# 38    FALSE
# 39    FALSE
# 40    FALSE
# 41    FALSE
# 42    FALSE
# 43    FALSE
# 44    FALSE
# 45    FALSE
# 46    FALSE
# 47    FALSE
# 48    FALSE

# %%
# List all worksheet titles to find the correct name
print([ws.title for ws in sheet.worksheets()])
# Then use the correct worksheet name, for example:
# ws2 = sheet.worksheet('To do')  # Replace with the correct name from the list above
# Out:
# ['To do']
