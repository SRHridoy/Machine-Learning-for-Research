# %% [markdown]
# ### Question: What is the risk for given data? speed = 160km/h, car_age = 10 years, experience = 5 years.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
url = 'https://raw.githubusercontent.com/rashakil-ds/Machine-Learning-with-Python/refs/heads/master/Datasets/car%20data.csv'
df = pd.read_csv(url)
df
# Out:
#      speed  car_age  experience  risk
# 0      172       22    8.104042    42
# 1       94       17   11.429461    36
# 2      186       20   14.819477    45
# 3      151       10   15.343897    38
# 4      100        6   16.455807    47
# ..     ...      ...         ...   ...
# 275    165       10    8.630563    20
# 276    130       26    6.656316    49
# 277    142       19   14.610983    20
# 278    204        7   13.874352    45
# 279    137        3    3.334615    68
#
# [280 rows x 4 columns]

# %%
df.experience
# Out:
# 0       8.104042
# 1      11.429461
# 2      14.819477
# 3      15.343897
# 4      16.455807
#          ...
# 275     8.630563
# 276     6.656316
# 277    14.610983
# 278    13.874352
# 279     3.334615
# Name: experience, Length: 280, dtype: float64

# %%
df.mean()
# Out:
# speed         151.925000
# car_age        15.332143
# experience     10.124917
# risk           53.035714
# dtype: float64

# %%
df.experience.mean()
# Out:
# 10.124916517871657

# %%
df.experience.median()
# Out:
# 10.582101444783259

# %%
exp_fit = df.experience.median()

# %%
df.experience = df.experience.fillna(exp_fit)

# %%
df.experience
# Out:
# 0       8.104042
# 1      11.429461
# 2      14.819477
# 3      15.343897
# 4      16.455807
#          ...
# 275     8.630563
# 276     6.656316
# 277    14.610983
# 278    13.874352
# 279     3.334615
# Name: experience, Length: 280, dtype: float64

# %%
df
# Out:
#      speed  car_age  experience  risk
# 0      172       22    8.104042    42
# 1       94       17   11.429461    36
# 2      186       20   14.819477    45
# 3      151       10   15.343897    38
# 4      100        6   16.455807    47
# ..     ...      ...         ...   ...
# 275    165       10    8.630563    20
# 276    130       26    6.656316    49
# 277    142       19   14.610983    20
# 278    204        7   13.874352    45
# 279    137        3    3.334615    68
#
# [280 rows x 4 columns]

# %%
reg = LinearRegression()

# %%
reg.fit(df[['speed','car_age','experience']],df.risk)
# Out:
# LinearRegression()

# %%
pred = reg.predict([[160,10,5]])
print(f'Predicted Risk is : ',pred)
# Out:
# Predicted Risk is :  [54.99630343]
# c:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
reg.coef_
# Out:
# array([-0.0302617 , -0.14473869, -0.27965041])

# %%
reg.intercept_
# Out:
# 62.683814381161525
